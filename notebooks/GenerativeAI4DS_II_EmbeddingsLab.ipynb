# %% [markdown]
# ## GenerativeAI4DS-II
# ## Lab. Embeddings
# ### Embeddings create a vector representation of a piece of text. This is useful because it means we can think about text in the vector space, and do things like semantic search where we look for pieces of text that are most similar in the vector space.

# %% [markdown]
# ### In this lab you will learn how to create embeddings out of any given text.

# %% [markdown]
# ### Get your [OpenAI API Key](https://platform.openai.com/account/api-keys)

# %%
#OPENAI_API_KEY="YOU-NEED_YOUR-OWN-API"

# %%
# !pip install --upgrade langchain;
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 1.7 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.3/328.3 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain-openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.7 MB/s eta 0:00:00
# ...

# %%
import os
import openai

# %%
from langchain_openai import OpenAIEmbeddings

# %% [markdown]
# ### 1. SetUp

# %%
## We rely on OpenAI to create embeddings
embeddings_model = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)

# %% [markdown]
# ### 2. Document embedding

# %%
document="My new electric car is awesome, it is silent, easy to drive and saves me lots of money"

# %%
embedded_document = embeddings_model.embed_query(document)

# %%
type(embedded_document)
# Out:
# list

# %%
print(embedded_document)
# Out:
# [-0.000289145449642092, 0.010045009665191174, 0.016958940774202347, -0.012632940895855427, -0.0129588283598423, -0.0016997280763462186, -0.007348448038101196, -0.046621110290288925, -0.019885540008544922, -0.020677894353866577, -0.010083349421620369, 0.024524647742509842, -0.004255710169672966, -0.002827555174008012, 0.011706397868692875, -0.012096185237169266, 0.027988003566861153, -0.0036710291169583797, 0.012530702166259289, 0.006850031670182943, -0.024537427350878716, 0.008952327072620392, -0.0070289503782987595, -0.0057190097868442535, -0.011840586550533772, -0.0013610604219138622, -0.005546480882912874, -0.005230178125202656, -0.014351839199662209, 0.006862811744213104, 0.011866146698594093, -0.0037477086298167706, -0.013009948655962944, -0.01851809024810791, -0.030416185036301613, -0.01763627491891384, -0.0065880436450243, 0.0018083573086187243, 0.026198815554380417, -0.013840642757713795, 0.011016282252967358, 0.007719065528362989, 0.0033675062004476786, 0.004488943610340357,
# ...

# %% [markdown]
# ### 3. List of Documents embedding

# %%
conversations=[
        "Hi there!",
        "Oh, hello!",
        "What's your name?",
        "My friends call me World",
        "Hello World!"
    ]

# %%
conversations
# Out:
# ['Hi there!',
#  'Oh, hello!',
#  "What's your name?",
#  'My friends call me World',
#  'Hello World!']

# %%
embedded_conversations = embeddings_model.embed_documents(conversations)

# %%
type(embedded_conversations)
# Out:
# list

# %%
print(embedded_conversations)
# Out:
# [[-0.020291371271014214, -0.007072774693369865, -0.022869061678647995, -0.02623402513563633, -0.03748443350195885, 0.021688148379325867, -0.006199788302183151, -0.009021914564073086, 0.008463202975690365, -0.01654546707868576, 0.02684352919459343, -0.007447364740073681, -0.01358683779835701, -0.024176953360438347, 0.0064854929223656654, -0.0202659759670496, 0.024278536438941956, -0.01469156239181757, 0.016418486833572388, -0.016558164730668068, -0.007256895303726196, -0.008120357990264893, 0.0046347626484930515, -0.0020491364412009716, -0.014843937940895557, -0.006047412753105164, -0.0020697705913335085, -0.022957947105169296, 0.019897732883691788, -0.031617969274520874, 0.012888449244201183, 0.01170753687620163, -0.008545740507543087, -0.009548880159854889, -0.0018237472977489233, -0.027402238920331, -0.008253686130046844, 0.0021189753897488117, 0.023986482992768288, -0.008767955005168915, 0.023542053997516632, 0.0009079055162146688, 0.009783793240785599, -0.013942381367087364, -0.0
# ...
